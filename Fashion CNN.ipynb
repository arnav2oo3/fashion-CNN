# %% [markdown]
# # Convolutional Neural Network(CNN) for Fashion MNIST with Tensorflow Keras

# %% [markdown]
# ![Kagg.jpg](attachment:Kagg.jpg)

# %% [markdown]
# Install **"visualkeras"** a python library to visualize neural network architecture

# %%
pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /opt/conda/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from visualkeras) (8.0.1)
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1. Loading all necessary *libraries* and *packages*

# %%
import os
import numpy as np
import seaborn as sns
import pandas as pd
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.python import keras
from tensorflow.python.keras.models import Sequential
from keras.layers import Dense, Conv2D, Activation, MaxPool2D, Flatten, Dropout, BatchNormalization
from keras.optimizers import RMSprop,Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import visualkeras
from keras.utils import plot_model
import math
from keras.optimizers import RMSprop

# %% [markdown]
# Setting the model *parameters*

# %%
Img_shape = 28
Num_classes = 10
test_size = 0.25
random_state = 1234
No_epochs = 100
Batch_size = 128

# %% [markdown]
# ### 2. Loading the [Zolando Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) Data

# %%
train_dataset = pd.read_csv("../input/fashionmnist/fashion-mnist_train.csv")
test_dataset = pd.read_csv("../input/fashionmnist/fashion-mnist_train.csv")

# %% [markdown]
# *Reading and Labeling the 10 Clothing categories*

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal',      'Shirt',   'Sneaker',  'Bag',   'Ankle boot']

# %% [markdown]
# ### 3. Pre-processing the data[[1]](https://www.kaggle.com/gpreda/cnn-with-tensorflow-keras-for-fashion-mnist)

# %%
def data_preprocessing(raw):
    label = tf.keras.utils.to_categorical(raw.label, 10)
    num_images = raw.shape[0]
    x_as_array = raw.values[:,1:]
    x_shaped_array = x_as_array.reshape(num_images, 28, 28, 1)
    image = x_shaped_array / 255
    return image, label

X, y = data_preprocessing(train_dataset)
X_test, y_test = data_preprocessing(test_dataset)

# %% [markdown]
# *Splitting the training data into training and validation set into a split ratio of 75-25 %*

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size, random_state=random_state)

# %% [markdown]
# > ### Convolutional Neural Network

# %% [markdown]
# ### 4. Train the model

# %% [markdown]
# *Lets keep the CNN model simple initially.*

# %%
# We are using sequential model which is linear stack of layers. The Sequential model is initialized first and then using add method we add rest of the layers

model = tf.keras.Sequential()

# First layer, which has a 2D Convolutional layer with kernel size as 3x3 and Max pooling operation 
model.add(Conv2D(32, (3,3), padding='same', input_shape=(28,28, 1)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# Second layer, which has a 2D Convolutional layer with kernel size as 3x3 & ReLU activation and Max pooling operation 
model.add(Conv2D(64, (3,3), padding='same', activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# Fully connected layer with ReLU activation function 
model.add(Flatten())
model.add(Dense(128, activation=tf.nn.relu))

# Output layer with softmax activation function
model.add(Dense(10, activation=tf.nn.softmax))

# %% [markdown]
# > Model's summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               401536
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 421,642
# Trainable params: 421,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# *3D visualization of our CNN model architecture*

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=536x150 at 0x7F82D5B0B490>

# %% [markdown]
# *A more elaborate and labelled way of visualization*

# %%
plot_model(model, to_file='model.png')

# %% [markdown]
# *Setting the parameters and compiling our model*

# %%
# Optimizer specified here is adam, loss is categorical crossentrophy and metric is accuracy
model.compile(optimizer='adam',
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %% [markdown]
# *Fit and Run the model with training and validation set of the data*

# %%
train_model = model.fit(X_train, y_train,
                  batch_size=Batch_size,
                  epochs=No_epochs,
                  verbose=1,
                  validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.5239 - accuracy: 0.8144 - val_loss: 0.3818 - val_accuracy: 0.8607
# Epoch 2/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.3371 - accuracy: 0.8802 - val_loss: 0.3264 - val_accuracy: 0.8799
# Epoch 3/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.2917 - accuracy: 0.8953 - val_loss: 0.3122 - val_accuracy: 0.8881
# Epoch 4/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.2643 - accuracy: 0.9050 - val_loss: 0.2884 - val_accuracy: 0.8971
# Epoch 5/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.2383 - accuracy: 0.9134 - val_loss: 0.2645 - val_accuracy: 0.9060
# Epoch 6/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.2157 - accuracy: 0.9216 - val_loss: 0.2603 - val_accuracy: 0.9073
# Epoch 7/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.1986 - accuracy: 0.9279 - val_loss: 0.2443 - val_accuracy: 0.9139
# Epoch 8/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.1800 - accuracy: 0.9341 - val_loss: 0.2628 - val_accuracy: 0.9062
# Epoch 9/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.1627 - accuracy: 0.9407 - val_loss: 0.2449 - val_accuracy: 0.9147
# Epoch 10/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.1461 - accuracy: 0.9466 - val_loss: 0.2662 - val_accuracy: 0.9083
# Epoch 11/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.1336 - accuracy: 0.9506 - val_loss: 0.2588 - val_accuracy: 0.9114
# Epoch 12/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.1197 - accuracy: 0.9555 - val_loss: 0.2500 - val_accuracy: 0.9171
# Epoch 13/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.1106 - accuracy: 0.9602 - val_loss: 0.2645 - val_accuracy: 0.9191
# Epoch 14/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0938 - accuracy: 0.9661 - val_loss: 0.2807 - val_accuracy: 0.9153
# Epoch 15/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0821 - accuracy: 0.9695 - val_loss: 0.2929 - val_accuracy: 0.9169
# Epoch 16/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0724 - accuracy: 0.9741 - val_loss: 0.3120 - val_accuracy: 0.9149
# Epoch 17/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0642 - accuracy: 0.9770 - val_loss: 0.3328 - val_accuracy: 0.9173
# Epoch 18/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.0594 - accuracy: 0.9788 - val_loss: 0.3359 - val_accuracy: 0.9125
# Epoch 19/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0494 - accuracy: 0.9827 - val_loss: 0.3346 - val_accuracy: 0.9193
# Epoch 20/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.0427 - accuracy: 0.9851 - val_loss: 0.3554 - val_accuracy: 0.9125
# Epoch 21/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.0410 - accuracy: 0.9852 - val_loss: 0.3773 - val_accuracy: 0.9149
# Epoch 22/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0348 - accuracy: 0.9883 - val_loss: 0.4028 - val_accuracy: 0.9135
# Epoch 23/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.4273 - val_accuracy: 0.9161
# Epoch 24/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0327 - accuracy: 0.9885 - val_loss: 0.4873 - val_accuracy: 0.9051
# Epoch 25/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0242 - accuracy: 0.9920 - val_loss: 0.4563 - val_accuracy: 0.9176
# Epoch 26/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.4472 - val_accuracy: 0.9170
# Epoch 27/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.4762 - val_accuracy: 0.9083
# Epoch 28/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0273 - accuracy: 0.9900 - val_loss: 0.4785 - val_accuracy: 0.9165
# Epoch 29/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0196 - accuracy: 0.9931 - val_loss: 0.4886 - val_accuracy: 0.9155
# Epoch 30/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.5264 - val_accuracy: 0.9181
# Epoch 31/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.5311 - val_accuracy: 0.9159
# Epoch 32/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.5156 - val_accuracy: 0.9135
# Epoch 33/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.5751 - val_accuracy: 0.9135
# Epoch 34/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.5443 - val_accuracy: 0.9181
# Epoch 35/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.5460 - val_accuracy: 0.9158
# Epoch 36/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.5443 - val_accuracy: 0.9164
# Epoch 37/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.6294 - val_accuracy: 0.9147
# Epoch 38/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.5835 - val_accuracy: 0.9147
# Epoch 39/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 0.5935 - val_accuracy: 0.9144
# Epoch 40/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0178 - accuracy: 0.9938 - val_loss: 0.6033 - val_accuracy: 0.9139
# Epoch 41/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.5972 - val_accuracy: 0.9146
# Epoch 42/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.6222 - val_accuracy: 0.9157
# Epoch 43/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.6430 - val_accuracy: 0.9161
# Epoch 44/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0195 - accuracy: 0.9926 - val_loss: 0.6239 - val_accuracy: 0.9138
# Epoch 45/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.6517 - val_accuracy: 0.9173
# Epoch 46/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.6987 - val_accuracy: 0.9125
# Epoch 47/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.6675 - val_accuracy: 0.9127
# Epoch 48/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.6572 - val_accuracy: 0.9143
# Epoch 49/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.7920 - val_accuracy: 0.9029
# Epoch 50/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.6520 - val_accuracy: 0.9143
# Epoch 51/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.6521 - val_accuracy: 0.9170
# Epoch 52/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.6707 - val_accuracy: 0.9141
# Epoch 53/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.7282 - val_accuracy: 0.9148
# Epoch 54/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.7153 - val_accuracy: 0.9163
# Epoch 55/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.7508 - val_accuracy: 0.9127
# Epoch 56/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.7104 - val_accuracy: 0.9175
# Epoch 57/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.7435 - val_accuracy: 0.9192
# Epoch 58/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.7275 - val_accuracy: 0.9017
# Epoch 59/100
# 352/352 [==============================] - 2s 5ms/step - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.7269 - val_accuracy: 0.9102
# Epoch 60/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.7317 - val_accuracy: 0.9152
# Epoch 61/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.7532 - val_accuracy: 0.9170
# Epoch 62/100
# 352/352 [==============================] - 2s 4ms/step - loss: 5.2451e-04 - accuracy: 0.9999 - val_loss: 0.7487 - val_accuracy: 0.9177
# Epoch 63/100
# 352/352 [==============================] - 2s 4ms/step - loss: 1.1076e-04 - accuracy: 1.0000 - val_loss: 0.7699 - val_accuracy: 0.9178
# Epoch 64/100
# 352/352 [==============================] - 2s 4ms/step - loss: 7.0174e-05 - accuracy: 1.0000 - val_loss: 0.7820 - val_accuracy: 0.9182
# Epoch 65/100
# 352/352 [==============================] - 2s 5ms/step - loss: 5.5346e-05 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.9180
# Epoch 66/100
# 352/352 [==============================] - 2s 5ms/step - loss: 4.5708e-05 - accuracy: 1.0000 - val_loss: 0.8029 - val_accuracy: 0.9186
# Epoch 67/100
# 352/352 [==============================] - 2s 4ms/step - loss: 3.8371e-05 - accuracy: 1.0000 - val_loss: 0.8108 - val_accuracy: 0.9185
# Epoch 68/100
# 352/352 [==============================] - 2s 4ms/step - loss: 3.2645e-05 - accuracy: 1.0000 - val_loss: 0.8207 - val_accuracy: 0.9191
# Epoch 69/100
# 352/352 [==============================] - 2s 4ms/step - loss: 2.8023e-05 - accuracy: 1.0000 - val_loss: 0.8317 - val_accuracy: 0.9193
# Epoch 70/100
# 352/352 [==============================] - 2s 4ms/step - loss: 2.4438e-05 - accuracy: 1.0000 - val_loss: 0.8375 - val_accuracy: 0.9199
# Epoch 71/100
# 352/352 [==============================] - 2s 4ms/step - loss: 2.1210e-05 - accuracy: 1.0000 - val_loss: 0.8456 - val_accuracy: 0.9199
# Epoch 72/100
# 352/352 [==============================] - 2s 5ms/step - loss: 1.8324e-05 - accuracy: 1.0000 - val_loss: 0.8550 - val_accuracy: 0.9190
# Epoch 73/100
# 352/352 [==============================] - 2s 6ms/step - loss: 1.5766e-05 - accuracy: 1.0000 - val_loss: 0.8604 - val_accuracy: 0.9195
# Epoch 74/100
# 352/352 [==============================] - 2s 5ms/step - loss: 1.3908e-05 - accuracy: 1.0000 - val_loss: 0.8712 - val_accuracy: 0.9207
# Epoch 75/100
# 352/352 [==============================] - 2s 6ms/step - loss: 1.1931e-05 - accuracy: 1.0000 - val_loss: 0.8769 - val_accuracy: 0.9204
# Epoch 76/100
# 352/352 [==============================] - 2s 5ms/step - loss: 1.0315e-05 - accuracy: 1.0000 - val_loss: 0.8855 - val_accuracy: 0.9203
# Epoch 77/100
# 352/352 [==============================] - 2s 5ms/step - loss: 8.9165e-06 - accuracy: 1.0000 - val_loss: 0.8934 - val_accuracy: 0.9203
# Epoch 78/100
# 352/352 [==============================] - 2s 5ms/step - loss: 7.7283e-06 - accuracy: 1.0000 - val_loss: 0.9011 - val_accuracy: 0.9206
# Epoch 79/100
# 352/352 [==============================] - 2s 5ms/step - loss: 6.6826e-06 - accuracy: 1.0000 - val_loss: 0.9118 - val_accuracy: 0.9211
# Epoch 80/100
# 352/352 [==============================] - 2s 5ms/step - loss: 5.7455e-06 - accuracy: 1.0000 - val_loss: 0.9193 - val_accuracy: 0.9210
# Epoch 81/100
# 352/352 [==============================] - 2s 4ms/step - loss: 4.9468e-06 - accuracy: 1.0000 - val_loss: 0.9268 - val_accuracy: 0.9205
# Epoch 82/100
# 352/352 [==============================] - 2s 4ms/step - loss: 4.2148e-06 - accuracy: 1.0000 - val_loss: 0.9387 - val_accuracy: 0.9215
# Epoch 83/100
# 352/352 [==============================] - 2s 4ms/step - loss: 3.6094e-06 - accuracy: 1.0000 - val_loss: 0.9476 - val_accuracy: 0.9213
# Epoch 84/100
# 352/352 [==============================] - 2s 4ms/step - loss: 3.0831e-06 - accuracy: 1.0000 - val_loss: 0.9561 - val_accuracy: 0.9209
# Epoch 85/100
# 352/352 [==============================] - 2s 5ms/step - loss: 2.6020e-06 - accuracy: 1.0000 - val_loss: 0.9659 - val_accuracy: 0.9206
# Epoch 86/100
# 352/352 [==============================] - 2s 4ms/step - loss: 2.2280e-06 - accuracy: 1.0000 - val_loss: 0.9713 - val_accuracy: 0.9210
# Epoch 87/100
# 352/352 [==============================] - 2s 4ms/step - loss: 1.9074e-06 - accuracy: 1.0000 - val_loss: 0.9868 - val_accuracy: 0.9217
# Epoch 88/100
# 352/352 [==============================] - 1s 4ms/step - loss: 1.6071e-06 - accuracy: 1.0000 - val_loss: 0.9967 - val_accuracy: 0.9215
# Epoch 89/100
# 352/352 [==============================] - 2s 4ms/step - loss: 1.3575e-06 - accuracy: 1.0000 - val_loss: 1.0082 - val_accuracy: 0.9217
# Epoch 90/100
# 352/352 [==============================] - 2s 4ms/step - loss: 1.1655e-06 - accuracy: 1.0000 - val_loss: 1.0149 - val_accuracy: 0.9219
# Epoch 91/100
# 352/352 [==============================] - 2s 4ms/step - loss: 9.8808e-07 - accuracy: 1.0000 - val_loss: 1.0246 - val_accuracy: 0.9219
# Epoch 92/100
# 352/352 [==============================] - 2s 6ms/step - loss: 8.2072e-07 - accuracy: 1.0000 - val_loss: 1.0367 - val_accuracy: 0.9215
# Epoch 93/100
# 352/352 [==============================] - 2s 5ms/step - loss: 7.0563e-07 - accuracy: 1.0000 - val_loss: 1.0467 - val_accuracy: 0.9211
# Epoch 94/100
# 352/352 [==============================] - 2s 4ms/step - loss: 5.8351e-07 - accuracy: 1.0000 - val_loss: 1.0552 - val_accuracy: 0.9217
# Epoch 95/100
# 352/352 [==============================] - 2s 4ms/step - loss: 4.9145e-07 - accuracy: 1.0000 - val_loss: 1.0684 - val_accuracy: 0.9216
# Epoch 96/100
# 352/352 [==============================] - 2s 4ms/step - loss: 4.1127e-07 - accuracy: 1.0000 - val_loss: 1.0809 - val_accuracy: 0.9214
# Epoch 97/100
# 352/352 [==============================] - 2s 4ms/step - loss: 3.4384e-07 - accuracy: 1.0000 - val_loss: 1.0929 - val_accuracy: 0.9211
# Epoch 98/100
# 352/352 [==============================] - 2s 4ms/step - loss: 2.9371e-07 - accuracy: 1.0000 - val_loss: 1.1000 - val_accuracy: 0.9217
# Epoch 99/100
# 352/352 [==============================] - 2s 5ms/step - loss: 2.4329e-07 - accuracy: 1.0000 - val_loss: 1.1101 - val_accuracy: 0.9217
# Epoch 100/100
# 352/352 [==============================] - 2s 4ms/step - loss: 2.0417e-07 - accuracy: 1.0000 - val_loss: 1.1252 - val_accuracy: 0.9213

# %% [markdown]
# ### 5. Evaluate the model

# %%
score = model.evaluate(X_test, y_test, steps=math.ceil(10000/32))
# checking the test loss and test accuracy
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2813 - accuracy: 0.9803
# Test loss: 0.2812943458557129
# Test accuracy: 0.9803166389465332

# %% [markdown]
# We got accuracy of *98.03 %* here, now lets try to add droput and batch normalization layers as our model is overfitting (we were getting the training accuracy of *100 %*)

# %% [markdown]
# ### 6. Tuning the Model

# %% [markdown]
# *Lets add Batch Normalization and Dropout layers (To avoid overfitting) to the model.*

# %%
model = Sequential()

model.add(Conv2D(32, 3, padding='same', activation='relu',kernel_initializer='he_normal', input_shape=(28,28, 1)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Conv2D(128, 3, padding='same', activation='relu'))
model.add(Conv2D(128, 3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.4))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.25))
model.add(Dense(10, activation='softmax'))

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=735x150 at 0x7F81E02A2FD0>

# %%
plot_model(model, to_file='model.png')

# %% [markdown]
# *Tweaking the learning rate in adam optimizer for better accuracy*

# %%
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = optimizer,
              loss=keras.losses.categorical_crossentropy, metrics=["accuracy"])

# %%
train_model = model.fit(X_train, y_train,
                  batch_size=Batch_size,
                  epochs=No_epochs,
                  verbose=1,
                  validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.5952 - accuracy: 0.7844 - val_loss: 0.4067 - val_accuracy: 0.8524
# Epoch 2/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.3983 - accuracy: 0.8540 - val_loss: 0.3315 - val_accuracy: 0.8719
# Epoch 3/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.3474 - accuracy: 0.8713 - val_loss: 0.3050 - val_accuracy: 0.8846
# Epoch 4/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.3146 - accuracy: 0.8826 - val_loss: 0.2688 - val_accuracy: 0.8974
# Epoch 5/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.2948 - accuracy: 0.8919 - val_loss: 0.2678 - val_accuracy: 0.9003
# Epoch 6/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.2836 - accuracy: 0.8944 - val_loss: 0.2541 - val_accuracy: 0.9044
# Epoch 7/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.2616 - accuracy: 0.9017 - val_loss: 0.2376 - val_accuracy: 0.9137
# Epoch 8/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2557 - accuracy: 0.9050 - val_loss: 0.2361 - val_accuracy: 0.9116
# Epoch 9/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.2489 - accuracy: 0.9071 - val_loss: 0.2398 - val_accuracy: 0.9115
# Epoch 10/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2391 - accuracy: 0.9096 - val_loss: 0.2435 - val_accuracy: 0.9102
# Epoch 11/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2315 - accuracy: 0.9122 - val_loss: 0.2469 - val_accuracy: 0.9061
# Epoch 12/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.2267 - accuracy: 0.9152 - val_loss: 0.2290 - val_accuracy: 0.9165
# Epoch 13/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2204 - accuracy: 0.9167 - val_loss: 0.2360 - val_accuracy: 0.9121
# Epoch 14/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2169 - accuracy: 0.9185 - val_loss: 0.2165 - val_accuracy: 0.9229
# Epoch 15/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2093 - accuracy: 0.9211 - val_loss: 0.2173 - val_accuracy: 0.9220
# Epoch 16/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2049 - accuracy: 0.9222 - val_loss: 0.2150 - val_accuracy: 0.9222
# Epoch 17/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.2032 - accuracy: 0.9242 - val_loss: 0.2134 - val_accuracy: 0.9241
# Epoch 18/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.2021 - accuracy: 0.9238 - val_loss: 0.2084 - val_accuracy: 0.9250
# Epoch 19/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1952 - accuracy: 0.9265 - val_loss: 0.2283 - val_accuracy: 0.9175
# Epoch 20/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1896 - accuracy: 0.9269 - val_loss: 0.2360 - val_accuracy: 0.9150
# Epoch 21/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1860 - accuracy: 0.9295 - val_loss: 0.2079 - val_accuracy: 0.9241
# Epoch 22/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.1809 - accuracy: 0.9321 - val_loss: 0.2030 - val_accuracy: 0.9259
# Epoch 23/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1756 - accuracy: 0.9338 - val_loss: 0.2059 - val_accuracy: 0.9269
# Epoch 24/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.1747 - accuracy: 0.9338 - val_loss: 0.2116 - val_accuracy: 0.9250
# Epoch 25/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1739 - accuracy: 0.9357 - val_loss: 0.2220 - val_accuracy: 0.9233
# Epoch 26/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1674 - accuracy: 0.9365 - val_loss: 0.2518 - val_accuracy: 0.9124
# Epoch 27/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1676 - accuracy: 0.9362 - val_loss: 0.2117 - val_accuracy: 0.9267
# Epoch 28/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1616 - accuracy: 0.9389 - val_loss: 0.2056 - val_accuracy: 0.9271
# Epoch 29/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1570 - accuracy: 0.9390 - val_loss: 0.2022 - val_accuracy: 0.9316
# Epoch 30/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1582 - accuracy: 0.9396 - val_loss: 0.2195 - val_accuracy: 0.9239
# Epoch 31/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1533 - accuracy: 0.9415 - val_loss: 0.2085 - val_accuracy: 0.9263
# Epoch 32/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1473 - accuracy: 0.9444 - val_loss: 0.2041 - val_accuracy: 0.9274
# Epoch 33/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1473 - accuracy: 0.9438 - val_loss: 0.2001 - val_accuracy: 0.9307
# Epoch 34/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1471 - accuracy: 0.9452 - val_loss: 0.2048 - val_accuracy: 0.9277
# Epoch 35/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1437 - accuracy: 0.9447 - val_loss: 0.2126 - val_accuracy: 0.9295
# Epoch 36/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1480 - accuracy: 0.9436 - val_loss: 0.1971 - val_accuracy: 0.9312
# Epoch 37/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1406 - accuracy: 0.9473 - val_loss: 0.2102 - val_accuracy: 0.9265
# Epoch 38/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1367 - accuracy: 0.9481 - val_loss: 0.2179 - val_accuracy: 0.9291
# Epoch 39/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1365 - accuracy: 0.9477 - val_loss: 0.2031 - val_accuracy: 0.9292
# Epoch 40/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1345 - accuracy: 0.9488 - val_loss: 0.2020 - val_accuracy: 0.9320
# Epoch 41/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1317 - accuracy: 0.9495 - val_loss: 0.2088 - val_accuracy: 0.9308
# Epoch 42/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1323 - accuracy: 0.9494 - val_loss: 0.2020 - val_accuracy: 0.9313
# Epoch 43/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1288 - accuracy: 0.9506 - val_loss: 0.2016 - val_accuracy: 0.9323
# Epoch 44/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.1306 - accuracy: 0.9495 - val_loss: 0.2095 - val_accuracy: 0.9327
# Epoch 45/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1225 - accuracy: 0.9530 - val_loss: 0.1962 - val_accuracy: 0.9337
# Epoch 46/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1269 - accuracy: 0.9519 - val_loss: 0.2077 - val_accuracy: 0.9319
# Epoch 47/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.1210 - accuracy: 0.9538 - val_loss: 0.2012 - val_accuracy: 0.9332
# Epoch 48/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1194 - accuracy: 0.9543 - val_loss: 0.2098 - val_accuracy: 0.9287
# Epoch 49/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.1180 - accuracy: 0.9553 - val_loss: 0.2202 - val_accuracy: 0.9281
# Epoch 50/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1206 - accuracy: 0.9543 - val_loss: 0.1979 - val_accuracy: 0.9327
# Epoch 51/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1181 - accuracy: 0.9556 - val_loss: 0.2620 - val_accuracy: 0.9179
# Epoch 52/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1146 - accuracy: 0.9566 - val_loss: 0.2105 - val_accuracy: 0.9325
# Epoch 53/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1151 - accuracy: 0.9567 - val_loss: 0.2145 - val_accuracy: 0.9330
# Epoch 54/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1125 - accuracy: 0.9577 - val_loss: 0.2155 - val_accuracy: 0.9337
# Epoch 55/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1114 - accuracy: 0.9583 - val_loss: 0.2070 - val_accuracy: 0.9338
# Epoch 56/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1136 - accuracy: 0.9570 - val_loss: 0.2209 - val_accuracy: 0.9318
# Epoch 57/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1124 - accuracy: 0.9579 - val_loss: 0.2300 - val_accuracy: 0.9307
# Epoch 58/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1067 - accuracy: 0.9600 - val_loss: 0.2076 - val_accuracy: 0.9329
# Epoch 59/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1048 - accuracy: 0.9607 - val_loss: 0.2155 - val_accuracy: 0.9327
# Epoch 60/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1043 - accuracy: 0.9608 - val_loss: 0.2225 - val_accuracy: 0.9310
# Epoch 61/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1030 - accuracy: 0.9613 - val_loss: 0.2156 - val_accuracy: 0.9331
# Epoch 62/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1103 - accuracy: 0.9588 - val_loss: 0.2165 - val_accuracy: 0.9335
# Epoch 63/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1025 - accuracy: 0.9619 - val_loss: 0.2319 - val_accuracy: 0.9303
# Epoch 64/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.1055 - accuracy: 0.9600 - val_loss: 0.2333 - val_accuracy: 0.9325
# Epoch 65/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1050 - accuracy: 0.9610 - val_loss: 0.2336 - val_accuracy: 0.9264
# Epoch 66/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1002 - accuracy: 0.9622 - val_loss: 0.2189 - val_accuracy: 0.9323
# Epoch 67/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.1001 - accuracy: 0.9621 - val_loss: 0.2346 - val_accuracy: 0.9321
# Epoch 68/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.1011 - accuracy: 0.9624 - val_loss: 0.2352 - val_accuracy: 0.9309
# Epoch 69/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0946 - accuracy: 0.9644 - val_loss: 0.2227 - val_accuracy: 0.9312
# Epoch 70/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0958 - accuracy: 0.9644 - val_loss: 0.2268 - val_accuracy: 0.9339
# Epoch 71/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0965 - accuracy: 0.9635 - val_loss: 0.2310 - val_accuracy: 0.9343
# Epoch 72/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.0958 - accuracy: 0.9639 - val_loss: 0.2264 - val_accuracy: 0.9339
# Epoch 73/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.0955 - accuracy: 0.9641 - val_loss: 0.2229 - val_accuracy: 0.9330
# Epoch 74/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0972 - accuracy: 0.9646 - val_loss: 0.2327 - val_accuracy: 0.9314
# Epoch 75/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0916 - accuracy: 0.9660 - val_loss: 0.2542 - val_accuracy: 0.9272
# Epoch 76/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0926 - accuracy: 0.9648 - val_loss: 0.2334 - val_accuracy: 0.9331
# Epoch 77/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.0918 - accuracy: 0.9659 - val_loss: 0.2437 - val_accuracy: 0.9284
# Epoch 78/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0921 - accuracy: 0.9654 - val_loss: 0.2438 - val_accuracy: 0.9315
# Epoch 79/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0936 - accuracy: 0.9640 - val_loss: 0.2236 - val_accuracy: 0.9331
# Epoch 80/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0904 - accuracy: 0.9673 - val_loss: 0.2331 - val_accuracy: 0.9337
# Epoch 81/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0893 - accuracy: 0.9678 - val_loss: 0.2458 - val_accuracy: 0.9315
# Epoch 82/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0879 - accuracy: 0.9666 - val_loss: 0.2296 - val_accuracy: 0.9339
# Epoch 83/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0852 - accuracy: 0.9686 - val_loss: 0.2294 - val_accuracy: 0.9328
# Epoch 84/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0860 - accuracy: 0.9683 - val_loss: 0.2695 - val_accuracy: 0.9264
# Epoch 85/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0865 - accuracy: 0.9671 - val_loss: 0.2396 - val_accuracy: 0.9341
# Epoch 86/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0872 - accuracy: 0.9676 - val_loss: 0.2416 - val_accuracy: 0.9300
# Epoch 87/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0838 - accuracy: 0.9696 - val_loss: 0.2656 - val_accuracy: 0.9260
# Epoch 88/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0813 - accuracy: 0.9695 - val_loss: 0.2260 - val_accuracy: 0.9331
# Epoch 89/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0834 - accuracy: 0.9680 - val_loss: 0.2358 - val_accuracy: 0.9353
# Epoch 90/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0846 - accuracy: 0.9686 - val_loss: 0.2223 - val_accuracy: 0.9330
# Epoch 91/100
# 352/352 [==============================] - 3s 8ms/step - loss: 0.0844 - accuracy: 0.9682 - val_loss: 0.2283 - val_accuracy: 0.9327
# Epoch 92/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0833 - accuracy: 0.9691 - val_loss: 0.2511 - val_accuracy: 0.9305
# Epoch 93/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.2529 - val_accuracy: 0.9317
# Epoch 94/100
# 352/352 [==============================] - 2s 6ms/step - loss: 0.0816 - accuracy: 0.9697 - val_loss: 0.2505 - val_accuracy: 0.9295
# Epoch 95/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0772 - accuracy: 0.9713 - val_loss: 0.2301 - val_accuracy: 0.9347
# Epoch 96/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0789 - accuracy: 0.9713 - val_loss: 0.2436 - val_accuracy: 0.9317
# Epoch 97/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0812 - accuracy: 0.9705 - val_loss: 0.2454 - val_accuracy: 0.9329
# Epoch 98/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.0783 - accuracy: 0.9710 - val_loss: 0.2810 - val_accuracy: 0.9251
# Epoch 99/100
# 352/352 [==============================] - 2s 7ms/step - loss: 0.0811 - accuracy: 0.9715 - val_loss: 0.2341 - val_accuracy: 0.9361
# Epoch 100/100
# 352/352 [==============================] - 3s 7ms/step - loss: 0.0739 - accuracy: 0.9717 - val_loss: 0.2378 - val_accuracy: 0.9343

# %%
score = model.evaluate(X_test, y_test, steps=math.ceil(10000/32))
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0737 - accuracy: 0.9811
# Test loss: 0.07374601066112518
# Test accuracy: 0.9811499714851379

# %% [markdown]
# Great ! we got an accuracy of *98.11 %* which is better than that of our earlier model.

# %% [markdown]
# ### 7. Visualizing the results

# %% [markdown]
# *Plotting 16 random images with predicted and real class of clothing*

# %%
labels = {0 : "T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat",
          5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle Boot"}

y_pred = model.predict(X_test)
X_test__ = X_test.reshape(X_test.shape[0], 28, 28)

fig, axis = plt.subplots(4, 4, figsize=(12, 14))
for i, ax in enumerate(axis.flat):
    ax.imshow(X_test__[i], cmap='binary')
    ax.set(title = f"Real Class is {labels[y_test[i].argmax()]}\nPredict Class is {labels[y_pred[i].argmax()]}");

# %% [markdown]
# *Plotting the confusion matrix*

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(y_test, axis = 1)
confusion_mtx = confusion_matrix(y_true, y_pred_classes) 

f,ax = plt.subplots(figsize = (12,12))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.1, cmap = "gist_yarg_r", linecolor="white", fmt='.0f', ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# > **References**
#
# 1. [CNN with Tensorflow|Keras for Fashion MNIST](https://www.kaggle.com/gpreda/cnn-with-tensorflow-keras-for-fashion-mnist) by Gabriel Preda
# 2. [Visualkeras](https://github.com/paulgavrikov/visualkeras/blob/master/examples/vgg16.py), Python package to help visualize Keras neural network architectures
# 3. [A Comprehensive Guide to Convolutional Neural Networks](https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53) by Sumit Saha
# 4. [Tinker with Neural Network](https://playground.tensorflow.org), a web based source to learn about Neural Networks
# 5. [Fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist), resources by Zolando research team

# %% [markdown]
# Please do *upvote* if you liked the notebook !

# %% [markdown]
# Check out the reference materials for more information about **Convolutional Neural Networks**.
